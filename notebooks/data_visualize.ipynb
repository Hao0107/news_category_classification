# %%
import pandas as pd

# %%
df = pd.read_csv('../data/raw_crawled_articles.csv')

# %%
df.head(3)
# Out:
#   category         source                                              title  \
# 0  Thời sự  vnexpress.net  Nhà máy đưa xe về quê đón công nhân trở lại sa...
# 1  Thời sự  vnexpress.net  Chuyến thăm tân gia trở thành ngày ly biệt 6 n...
# 2  Thời sự  vnexpress.net  Lao động nhận mừng tuổi, dầu ăn ngày đầu đi là...
#
#                                             abstract  \
# 0  Sau Tết, nhiều doanh nghiệp tại TP HCM tổ chức...
# 1  Lào CaiSau bữa cơm mừng tân gia ở xã Bảo Ái, 2...
# 2  Mùng 7 Tết, nhiều doanh nghiệp khai xuân bằng ...
#
#                                                  url
# 0  https://vnexpress.net/nha-may-dua-xe-ve-que-do...
# 1  https://vnexpress.net/chuyen-tham-tan-gia-tro-...
# 2  https://vnexpress.net/lao-dong-nhan-mung-tuoi-...

# %%
df.columns
# Out:
# Index(['category', 'source', 'title', 'abstract', 'url'], dtype='object')
